# %% [markdown]
# # Best Gradient Boosting and XGBoost models
#
# The models developed in this notebook were used in the report.

# %%
# Import library
# %pip install seaborn
# %pip install openpyxl
# %pip install mlxtend
# %pip install xgboost
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.preprocessing import PolynomialFeatures
from xgboost import XGBRegressor
import itertools

# %% [markdown]
# ## Cleaning
# Renaming df columns & adding two new columns:
# - Year
# - Quarter

# %%
df = pd.read_csv('data/master_normalised.csv')
df= df.rename(columns={
     'quarter': "Time_Period",
     'Total Demand': "Electricity_Demand",
     'GDP (AUD, Millions)':"GDP",
     'Population (000,s)':"Population",
     'Coal_Price (PCOALAUUSDM)':"Coal_Price",
     'Premium unleaded petrol (95 RON) (cpl)':"Premium_Unleaded_Petrol",
     'Regular unleaded petrol (91 RON) (cpl)':"Regular_Unleaded_Petrol",
     'Automotive diesel (cpl)':"Automotive_Diesel",
     'Automotive LPG (cpl)':"Automotive_LPG",
     'Temperature(max)':"Temperature_Max",
     'Temperature(avg)':"Temperature_Avg",
     'Temperature(min)':"Temperature_Min",
     'electricity_price':"Electricity_Price",
     'renewable_energy':"Renewables_Production",
     'oil_price': 'Oil_Price'
})
df.columns.tolist()

df['Time_Period'] = pd.to_datetime(df['Time_Period'])
# Extract the year
df['Year'] = df['Time_Period'].dt.year
# Extract the quarter
df['Quarter'] = df['Time_Period'].dt.quarter
df.head()
# Out:
#   Time_Period  Electricity_Demand       GDP  Population  Coal_Price  \
# 0  2010-01-01            0.930894  0.000000    0.000000    0.558774
# 1  2010-04-01            0.860334  0.118536    0.018352    0.632759
# 2  2010-07-01            1.000000  0.141274    0.038033    0.564323
# 3  2010-10-01            0.737070  0.232885    0.056494    0.719280
# 4  2011-01-01            0.858217  0.120926    0.082599    1.000000
#
#    Premium_Unleaded_Petrol  Regular_Unleaded_Petrol  Automotive_Diesel  \
# 0                    0.275                 0.363636           0.234043
# 1                    0.350                 0.431818           0.340426
# 2                    0.250                 0.318182           0.297872
# 3                    0.275                 0.363636           0.319149
# 4                    0.575                 0.613636           0.595745
#
#    Automotive_LPG  Temperature_Max  Temperature_Min  Electricity_Price  \
# 0        0.228571         0.969492         0.971787           0.303922
# 1        0.171429         0.510734         0.173197           0.250000
# 2        0.000000         0.183051         0.155956           0.196078
# 3        0.200000         0.606780         0.611285           0.142157
# 4        0.542857         0.912994         0.978840           0.088235
#
#    Renewables_Production  Oil_Price  Temperature_Avg  Year  Quarter
# 0               0.000000   0.652967         1.000000  2010        1
# 1               0.027860   0.640241         0.283133  2010        2
# 2               0.055720   0.617716         0.134948  2010        3
# 3               0.083580   0.734558         0.662522  2010        4
# 4               0.111441   0.848923         0.979572  2011        1

# %% [markdown]
# ## Correlation Analysis

# %%
# Setting 'Time_Period' as index
df.set_index('Time_Period', inplace=True)

# Exclude Year and Quarter columns from correlation analysis
df_analysis = df.drop(columns=['Year', 'Quarter'], errors='ignore')

# Calculate correlation matrix
corr_matrix = df_analysis.corr()

# Plot
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# Display correlation values with Electricity_Demand specifically
electricity_demand_correlation = corr_matrix['Electricity_Demand'].sort_values(ascending=False)
print(electricity_demand_correlation)
# Out:
# Electricity_Demand         1.000000
# Coal_Price                 0.371817
# Oil_Price                  0.357952
# Automotive_Diesel          0.076427
# Regular_Unleaded_Petrol   -0.017037
# Premium_Unleaded_Petrol   -0.085003
# Temperature_Min           -0.123126
# Temperature_Max           -0.138913
# Temperature_Avg           -0.159489
# Electricity_Price         -0.327437
# Automotive_LPG            -0.346566
# Population                -0.676495
# Renewables_Production     -0.732432
# GDP                       -0.738298
# Name: Electricity_Demand, dtype: float64

# %% [markdown]
# ## Train/Test Split
# - 2010-2018 as training
# - 2019-2020 as testing
# - Average temperature used for temperature

# %%
# Splitting the data according to the specified years and quarters
train = df[(df['Year'] < 2018)]
test = df[((df['Year'] >= 2018) & (df['Year'] < 2020))]

def test_split(features: list = None):
    _train = df[(df['Year'] < 2018)]
    _test = df[((df['Year'] >= 2018) & (df['Year'] < 2020))]

    if features:
        _X_train = _train[features]
        _y_train = _train['Electricity_Demand']
        _X_test = _test[features]
        _y_test = _test['Electricity_Demand']
    else:
        _X_train = _train.drop(['Electricity_Demand', 'Year', 'Quarter', 'Temperature_Min', 'Temperature_Max'], axis=1)
        _y_train = _train['Electricity_Demand']
        _X_test = _test.drop(['Electricity_Demand', 'Year', 'Quarter','Temperature_Min', 'Temperature_Max'], axis=1)
        _y_test = _test['Electricity_Demand']
    return _X_train, _y_train, _X_test, _y_test

def train_model2(in_model):
    # Fit the model on the training data
    in_model.fit(X_train, y_train)

    # Get training set scores
    y_pred_train = in_model.predict(X_train)
    train_rmse = np.sqrt(mean_squared_error(y_train, y_pred_train))
    train_r2 = r2_score(y_train, y_pred_train)
    
    # Predict on the test set
    y_pred = in_model.predict(X_test)
    
    # Calculate the RMSE for the test set
    test_rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Calculate the R-squared value for the test set
    test_r2 = r2_score(y_test, y_pred)
    
    # print(f"{in_model.__class__.__name__} Train RMSE, R-squared: {train_rmse:6.4f}, {train_r2:6.4f}")
    # print(f"{in_model.__class__.__name__} Test  RMSE, R-squared: {test_rmse:6.4f}, {test_r2:6.4f}")
    return in_model, test_rmse, test_r2, train_rmse, train_r2
    
def find_better_model(model_class, params):
    min_rmse, best_model, best_param_set, best_r2 = None, None, None, None
    results = []
    for param_set in itertools.product(*params.values()):
        kw_args = dict(zip(params.keys(), param_set))
        # print(f'{model_class.__name__} | ' + ', '.join([f'{k}: {v}' for k, v in kw_args.items()]))
        model = model_class(**kw_args)
        out_model, rmse, r2, train_rmse, train_r2 = train_model2(model)
        results.append({**kw_args, 'test_rmse': rmse, 'test_r2': r2, 'train_rmse': train_rmse, 'train_r2': train_r2})
        if min_rmse is None or rmse < min_rmse:
            min_rmse = rmse
            best_r2 = r2
            best_model = out_model
            best_param_set = kw_args
    print(f'Best model with params {model_class.__name__}({best_param_set})\nRMSE: {min_rmse:0.4f}\nR-squared: {best_r2:0.4f}')
    return best_model, pd.DataFrame(results), min_rmse

def scatterplot(data, x, y, x2, y2, hue, style, title, title2, file_name='scatterplot.png'):
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10, 10))
    sns.scatterplot(data=data, x=x, y=y, hue=hue, style=style, ax=ax1)
    ax1.title.set_text(title)
    sns.scatterplot(data=data, x=x2, y=y2, hue=hue, style=style, ax=ax2)
    ax2.title.set_text(title2)
    sns.scatterplot(data=data, x=x, y=x2, hue=hue, style=style, ax=ax3)
    ax3.title.set_text('Training')
    sns.scatterplot(data=data, x=y, y=y2, hue=hue, style=style, ax=ax4)
    ax4.title.set_text('Test')
    sns.set_style("whitegrid")
    plt.tight_layout()
    plt.savefig(file_name, dpi=200)
    plt.show()
    # RMSE vs. Number of Features
    # plt.figure(figsize=(10, 6))
    # plt.plot(range(1, len(rmse_values) + 1), rmse_values, marker='o', linestyle='-')
    # plt.title(f'RMSE vs. Number of Features ({model_name})')
    # plt.xlabel('Number of Features')
    # plt.ylabel('RMSE')
    # plt.grid(True)
    # plt.show()

def plot_test(in_model):
    plt.figure(figsize=(8, 4.5))
    plt.title(f'{in_model.__class__.__name__} Model')
    plt.scatter(test.reset_index()['Time_Period'], y_test)
    sns.set_style("whitegrid")
    plt.tight_layout()
    plt.plot(test.reset_index()['Time_Period'], in_model.predict(X_test), color='black')
    plt.show()

def plot_full(in_model, file_name='plot_full.png'):
    plt.figure(figsize=(9, 4.5))
    plt.title(f'{in_model.__class__.__name__} Model')
    plt.scatter(train.reset_index()['Time_Period'], y_train)
    plt.scatter(test.reset_index()['Time_Period'], y_test)
    plt.plot(train.reset_index()['Time_Period'], in_model.predict(X_train), color='black')
    plt.plot(test.reset_index()['Time_Period'], in_model.predict(X_test), color='green')
    plt.ylim(ymin=0)
    sns.set_style("whitegrid")
    # plt.tight_layout()
    plt.title(f'{in_model.__class__.__name__} Model Prediction Performance - Training vs Test')
    plt.xlabel('Year')
    plt.ylabel('Electicity Demand (Normalised)')
    plt.savefig(file_name, dpi=200, bbox_inches='tight')
    plt.show()

def find_best_features(model_class, hyper_parameters, features = None, min_features: int = 1, max_features: int = 5):
    global X_train, y_train, X_test, y_test
    if not features:
        features = ['GDP', 'Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production', 'Oil_Price']
    combinations = []
    for i in range(min_features, max_features + 1):
        combinations.extend(itertools.combinations(features, i))
    print(len(combinations), 'combinations')

    results = []
    min_rmse = None
    for i, columns in enumerate(combinations, start=1):
        X_train, y_train, X_test, y_test = test_split(list(columns))
        model, df_results, best_rmse = find_better_model(model_class, hyper_parameters)
        mean_rmse = df_results['test_rmse'].mean()
        max_r2 = df_results['test_r2'].max()
        results.append([columns, best_rmse, mean_rmse, max_r2])
        print(f'{i:3d}  {best_rmse:6.4f} {columns}')
    result = pd.DataFrame(results, columns = ['features', 'min_rmse', 'mean_rmse', 'max_r2'])
    return result

# %%
X_train, y_train, X_test, y_test = test_split()
model, df_results, best_rmse = find_better_model(GradientBoostingRegressor, {
                'random_state': [0],
                'n_estimators': [100, 200, 300],
                'learning_rate': [0.1, 0.125, 0.15, 0.175, 0.2, 0.225, 0.25, 0.3],
                'max_depth': [4, 5, 6, 7, 10]
                })
scatterplot(data=df_results, x='train_r2', y='test_r2', x2='train_rmse', y2='test_rmse', hue='n_estimators', style='random_state', title='R-squared', title2='RMSE')
plot_full(model)
# Out:
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 5})
# RMSE: 0.0370
# R-squared: 0.7964

# %%
best_features = find_best_features(GradientBoostingRegressor, {
                'random_state': [0],
                'n_estimators': [200],
                'learning_rate': [0.1, 0.125, 0.15, 0.175, 0.2, 0.225, 0.25, 0.3],
                'max_depth': [3, 4, 5]
                },
                min_features=1, max_features=6)
best_features['num_features'] = best_features['features'].apply(lambda x: len(x))
best_features.sort_values('min_rmse')
# Out:
# 465 combinations
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1073
# R-squared: -0.7097
#   1  0.1073 ('GDP',)
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1129
# R-squared: -0.8919
#   2  0.1129 ('Population',)
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1650
# R-squared: -3.0445
#   3  0.1650 ('Coal_Price',)
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1733
# R-squared: -3.4617
#   4  0.1733 ('Regular_Unleaded_Petrol',)
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1457
# R-squared: -2.1542
#   5  0.1457 ('Automotive_LPG',)
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1038
# R-squared: -0.5992
#   6  0.1038 ('Temperature_Avg',)
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1524
# R-squared: -2.4516
#   7  0.1524 ('Electricity_Price',)
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1128
# R-squared: -0.8902
#   8  0.1128 ('Renewables_Production',)
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1207
# R-squared: -1.1639
#   9  0.1207 ('Oil_Price',)
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 5})
# RMSE: 0.1023
# R-squared: -0.5558
#  10  0.1023 ('GDP', 'Population')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.1017
# R-squared: -0.5356
#  11  0.1017 ('GDP', 'Coal_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0881
# R-squared: -0.1518
#  12  0.0881 ('GDP', 'Regular_Unleaded_Petrol')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0926
# R-squared: -0.2748
#  13  0.0926 ('GDP', 'Automotive_LPG')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 3})
# RMSE: 0.0362
# R-squared: 0.8053
#  14  0.0362 ('GDP', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0885
# R-squared: -0.1630
#  15  0.0885 ('GDP', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.1025
# R-squared: -0.5600
#  16  0.1025 ('GDP', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 5})
# RMSE: 0.1075
# R-squared: -0.7165
#  17  0.1075 ('GDP', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 4})
# RMSE: 0.1169
# R-squared: -1.0291
#  18  0.1169 ('Population', 'Coal_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 4})
# RMSE: 0.0905
# R-squared: -0.2165
#  19  0.0905 ('Population', 'Regular_Unleaded_Petrol')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.1055
# R-squared: -0.6530
#  20  0.1055 ('Population', 'Automotive_LPG')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0337
# R-squared: 0.8316
#  21  0.0337 ('Population', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 5})
# RMSE: 0.0952
# R-squared: -0.3473
#  22  0.0952 ('Population', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1130
# R-squared: -0.8971
#  23  0.1130 ('Population', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 5})
# RMSE: 0.1174
# R-squared: -1.0464
#  24  0.1174 ('Population', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 5})
# RMSE: 0.1191
# R-squared: -1.1082
#  25  0.1191 ('Coal_Price', 'Regular_Unleaded_Petrol')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 3})
# RMSE: 0.0830
# R-squared: -0.0238
#  26  0.0830 ('Coal_Price', 'Automotive_LPG')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 3})
# RMSE: 0.1292
# R-squared: -1.4779
#  27  0.1292 ('Coal_Price', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1242
# R-squared: -1.2909
#  28  0.1242 ('Coal_Price', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 4})
# RMSE: 0.1243
# R-squared: -1.2936
#  29  0.1243 ('Coal_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.125, 'max_depth': 3})
# RMSE: 0.1053
# R-squared: -0.6459
#  30  0.1053 ('Coal_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 4})
# RMSE: 0.1274
# R-squared: -1.4104
#  31  0.1274 ('Regular_Unleaded_Petrol', 'Automotive_LPG')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 3})
# RMSE: 0.1213
# R-squared: -1.1855
#  32  0.1213 ('Regular_Unleaded_Petrol', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 4})
# RMSE: 0.1364
# R-squared: -1.7626
#  33  0.1364 ('Regular_Unleaded_Petrol', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 5})
# RMSE: 0.0915
# R-squared: -0.2439
#  34  0.0915 ('Regular_Unleaded_Petrol', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.1058
# R-squared: -0.6643
#  35  0.1058 ('Regular_Unleaded_Petrol', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0889
# R-squared: -0.1727
#  36  0.0889 ('Automotive_LPG', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0956
# R-squared: -0.3570
#  37  0.0956 ('Automotive_LPG', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1097
# R-squared: -0.7885
#  38  0.1097 ('Automotive_LPG', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 4})
# RMSE: 0.1000
# R-squared: -0.4868
#  39  0.1000 ('Automotive_LPG', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 5})
# RMSE: 0.0393
# R-squared: 0.7701
#  40  0.0393 ('Temperature_Avg', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 3})
# RMSE: 0.0343
# R-squared: 0.8256
#  41  0.0343 ('Temperature_Avg', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 3})
# RMSE: 0.0269
# R-squared: 0.8923
#  42  0.0269 ('Temperature_Avg', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0965
# R-squared: -0.3835
#  43  0.0965 ('Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 3})
# RMSE: 0.1125
# R-squared: -0.8785
#  44  0.1125 ('Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.1141
# R-squared: -0.9333
#  45  0.1141 ('Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.125, 'max_depth': 5})
# RMSE: 0.1010
# R-squared: -0.5167
#  46  0.1010 ('GDP', 'Population', 'Coal_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 3})
# RMSE: 0.0853
# R-squared: -0.0796
#  47  0.0853 ('GDP', 'Population', 'Regular_Unleaded_Petrol')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 4})
# RMSE: 0.0905
# R-squared: -0.2157
#  48  0.0905 ('GDP', 'Population', 'Automotive_LPG')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.0368
# R-squared: 0.7988
#  49  0.0368 ('GDP', 'Population', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0765
# R-squared: 0.1308
#  50  0.0765 ('GDP', 'Population', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1027
# R-squared: -0.5659
#  51  0.1027 ('GDP', 'Population', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 4})
# RMSE: 0.1023
# R-squared: -0.5546
#  52  0.1023 ('GDP', 'Population', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.0901
# R-squared: -0.2063
#  53  0.0901 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 5})
# RMSE: 0.0950
# R-squared: -0.3395
#  54  0.0950 ('GDP', 'Coal_Price', 'Automotive_LPG')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 3})
# RMSE: 0.0386
# R-squared: 0.7783
#  55  0.0386 ('GDP', 'Coal_Price', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 5})
# RMSE: 0.0792
# R-squared: 0.0675
#  56  0.0792 ('GDP', 'Coal_Price', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 4})
# RMSE: 0.1014
# R-squared: -0.5280
#  57  0.1014 ('GDP', 'Coal_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.125, 'max_depth': 5})
# RMSE: 0.1013
# R-squared: -0.5234
#  58  0.1013 ('GDP', 'Coal_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.0867
# R-squared: -0.1161
#  59  0.0867 ('GDP', 'Regular_Unleaded_Petrol', 'Automotive_LPG')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 5})
# RMSE: 0.0389
# R-squared: 0.7747
#  60  0.0389 ('GDP', 'Regular_Unleaded_Petrol', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0749
# R-squared: 0.1657
#  61  0.0749 ('GDP', 'Regular_Unleaded_Petrol', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0878
# R-squared: -0.1443
#  62  0.0878 ('GDP', 'Regular_Unleaded_Petrol', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 5})
# RMSE: 0.0998
# R-squared: -0.4800
#  63  0.0998 ('GDP', 'Regular_Unleaded_Petrol', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 5})
# RMSE: 0.0381
# R-squared: 0.7839
#  64  0.0381 ('GDP', 'Automotive_LPG', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0798
# R-squared: 0.0540
#  65  0.0798 ('GDP', 'Automotive_LPG', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0911
# R-squared: -0.2320
#  66  0.0911 ('GDP', 'Automotive_LPG', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0941
# R-squared: -0.3152
#  67  0.0941 ('GDP', 'Automotive_LPG', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 3})
# RMSE: 0.0378
# R-squared: 0.7878
#  68  0.0378 ('GDP', 'Temperature_Avg', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.0338
# R-squared: 0.8307
#  69  0.0338 ('GDP', 'Temperature_Avg', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0396
# R-squared: 0.7674
#  70  0.0396 ('GDP', 'Temperature_Avg', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 4})
# RMSE: 0.0781
# R-squared: 0.0930
#  71  0.0781 ('GDP', 'Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 5})
# RMSE: 0.0830
# R-squared: -0.0242
#  72  0.0830 ('GDP', 'Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 5})
# RMSE: 0.1039
# R-squared: -0.6032
#  73  0.1039 ('GDP', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.0979
# R-squared: -0.4240
#  74  0.0979 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.1027
# R-squared: -0.5678
#  75  0.1027 ('Population', 'Coal_Price', 'Automotive_LPG')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.0427
# R-squared: 0.7290
#  76  0.0427 ('Population', 'Coal_Price', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 4})
# RMSE: 0.1079
# R-squared: -0.7289
#  77  0.1079 ('Population', 'Coal_Price', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.1211
# R-squared: -1.1795
#  78  0.1211 ('Population', 'Coal_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.1146
# R-squared: -0.9493
#  79  0.1146 ('Population', 'Coal_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.0965
# R-squared: -0.3842
#  80  0.0965 ('Population', 'Regular_Unleaded_Petrol', 'Automotive_LPG')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0330
# R-squared: 0.8382
#  81  0.0330 ('Population', 'Regular_Unleaded_Petrol', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 4})
# RMSE: 0.0906
# R-squared: -0.2203
#  82  0.0906 ('Population', 'Regular_Unleaded_Petrol', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0896
# R-squared: -0.1934
#  83  0.0896 ('Population', 'Regular_Unleaded_Petrol', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 5})
# RMSE: 0.1054
# R-squared: -0.6516
#  84  0.1054 ('Population', 'Regular_Unleaded_Petrol', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 4})
# RMSE: 0.0340
# R-squared: 0.8283
#  85  0.0340 ('Population', 'Automotive_LPG', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 5})
# RMSE: 0.0946
# R-squared: -0.3301
#  86  0.0946 ('Population', 'Automotive_LPG', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 3})
# RMSE: 0.1064
# R-squared: -0.6805
#  87  0.1064 ('Population', 'Automotive_LPG', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 5})
# RMSE: 0.1029
# R-squared: -0.5734
#  88  0.1029 ('Population', 'Automotive_LPG', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0343
# R-squared: 0.8255
#  89  0.0343 ('Population', 'Temperature_Avg', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0323
# R-squared: 0.8452
#  90  0.0323 ('Population', 'Temperature_Avg', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0342
# R-squared: 0.8264
#  91  0.0342 ('Population', 'Temperature_Avg', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0965
# R-squared: -0.3840
#  92  0.0965 ('Population', 'Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 5})
# RMSE: 0.0970
# R-squared: -0.3978
#  93  0.0970 ('Population', 'Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 4})
# RMSE: 0.1139
# R-squared: -0.9264
#  94  0.1139 ('Population', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0766
# R-squared: 0.1273
#  95  0.0766 ('Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.1158
# R-squared: -0.9908
#  96  0.1158 ('Coal_Price', 'Regular_Unleaded_Petrol', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 4})
# RMSE: 0.0984
# R-squared: -0.4370
#  97  0.0984 ('Coal_Price', 'Regular_Unleaded_Petrol', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0966
# R-squared: -0.3853
#  98  0.0966 ('Coal_Price', 'Regular_Unleaded_Petrol', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 3})
# RMSE: 0.0757
# R-squared: 0.1489
#  99  0.0757 ('Coal_Price', 'Regular_Unleaded_Petrol', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0317
# R-squared: 0.8509
# 100  0.0317 ('Coal_Price', 'Automotive_LPG', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 3})
# RMSE: 0.0956
# R-squared: -0.3568
# 101  0.0956 ('Coal_Price', 'Automotive_LPG', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 5})
# RMSE: 0.1119
# R-squared: -0.8588
# 102  0.1119 ('Coal_Price', 'Automotive_LPG', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0998
# R-squared: -0.4802
# 103  0.0998 ('Coal_Price', 'Automotive_LPG', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0688
# R-squared: 0.2962
# 104  0.0688 ('Coal_Price', 'Temperature_Avg', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.0442
# R-squared: 0.7102
# 105  0.0442 ('Coal_Price', 'Temperature_Avg', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 3})
# RMSE: 0.1270
# R-squared: -1.3965
# 106  0.1270 ('Coal_Price', 'Temperature_Avg', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.1126
# R-squared: -0.8819
# 107  0.1126 ('Coal_Price', 'Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.0974
# R-squared: -0.4099
# 108  0.0974 ('Coal_Price', 'Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 4})
# RMSE: 0.1128
# R-squared: -0.8890
# 109  0.1128 ('Coal_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.125, 'max_depth': 5})
# RMSE: 0.1081
# R-squared: -0.7370
# 110  0.1081 ('Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.1061
# R-squared: -0.6718
# 111  0.1061 ('Regular_Unleaded_Petrol', 'Automotive_LPG', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.1056
# R-squared: -0.6559
# 112  0.1056 ('Regular_Unleaded_Petrol', 'Automotive_LPG', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 5})
# RMSE: 0.0917
# R-squared: -0.2491
# 113  0.0917 ('Regular_Unleaded_Petrol', 'Automotive_LPG', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 4})
# RMSE: 0.0375
# R-squared: 0.7911
# 114  0.0375 ('Regular_Unleaded_Petrol', 'Temperature_Avg', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0327
# R-squared: 0.8408
# 115  0.0327 ('Regular_Unleaded_Petrol', 'Temperature_Avg', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0209
# R-squared: 0.9352
# 116  0.0209 ('Regular_Unleaded_Petrol', 'Temperature_Avg', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.0946
# R-squared: -0.3280
# 117  0.0946 ('Regular_Unleaded_Petrol', 'Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 3})
# RMSE: 0.1031
# R-squared: -0.5778
# 118  0.1031 ('Regular_Unleaded_Petrol', 'Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 5})
# RMSE: 0.1006
# R-squared: -0.5033
# 119  0.1006 ('Regular_Unleaded_Petrol', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.0366
# R-squared: 0.8011
# 120  0.0366 ('Automotive_LPG', 'Temperature_Avg', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.125, 'max_depth': 4})
# RMSE: 0.0362
# R-squared: 0.8052
# 121  0.0362 ('Automotive_LPG', 'Temperature_Avg', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 4})
# RMSE: 0.0257
# R-squared: 0.9020
# 122  0.0257 ('Automotive_LPG', 'Temperature_Avg', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 5})
# RMSE: 0.0943
# R-squared: -0.3214
# 123  0.0943 ('Automotive_LPG', 'Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.0939
# R-squared: -0.3085
# 124  0.0939 ('Automotive_LPG', 'Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 4})
# RMSE: 0.1019
# R-squared: -0.5421
# 125  0.1019 ('Automotive_LPG', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.0353
# R-squared: 0.8149
# 126  0.0353 ('Temperature_Avg', 'Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0323
# R-squared: 0.8447
# 127  0.0323 ('Temperature_Avg', 'Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.125, 'max_depth': 3})
# RMSE: 0.0343
# R-squared: 0.8249
# 128  0.0343 ('Temperature_Avg', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 5})
# RMSE: 0.1015
# R-squared: -0.5314
# 129  0.1015 ('Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0877
# R-squared: -0.1416
# 130  0.0877 ('GDP', 'Population', 'Coal_Price', 'Regular_Unleaded_Petrol')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 4})
# RMSE: 0.0924
# R-squared: -0.2685
# 131  0.0924 ('GDP', 'Population', 'Coal_Price', 'Automotive_LPG')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.0402
# R-squared: 0.7602
# 132  0.0402 ('GDP', 'Population', 'Coal_Price', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 3})
# RMSE: 0.0762
# R-squared: 0.1366
# 133  0.0762 ('GDP', 'Population', 'Coal_Price', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.1009
# R-squared: -0.5129
# 134  0.1009 ('GDP', 'Population', 'Coal_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 5})
# RMSE: 0.1008
# R-squared: -0.5088
# 135  0.1008 ('GDP', 'Population', 'Coal_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 4})
# RMSE: 0.0833
# R-squared: -0.0299
# 136  0.0833 ('GDP', 'Population', 'Regular_Unleaded_Petrol', 'Automotive_LPG')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.0367
# R-squared: 0.7999
# 137  0.0367 ('GDP', 'Population', 'Regular_Unleaded_Petrol', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 3})
# RMSE: 0.0713
# R-squared: 0.2450
# 138  0.0713 ('GDP', 'Population', 'Regular_Unleaded_Petrol', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0858
# R-squared: -0.0928
# 139  0.0858 ('GDP', 'Population', 'Regular_Unleaded_Petrol', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.0898
# R-squared: -0.1976
# 140  0.0898 ('GDP', 'Population', 'Regular_Unleaded_Petrol', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.0365
# R-squared: 0.8018
# 141  0.0365 ('GDP', 'Population', 'Automotive_LPG', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.0738
# R-squared: 0.1921
# 142  0.0738 ('GDP', 'Population', 'Automotive_LPG', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.125, 'max_depth': 5})
# RMSE: 0.0912
# R-squared: -0.2354
# 143  0.0912 ('GDP', 'Population', 'Automotive_LPG', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 4})
# RMSE: 0.0899
# R-squared: -0.2012
# 144  0.0899 ('GDP', 'Population', 'Automotive_LPG', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 5})
# RMSE: 0.0363
# R-squared: 0.8039
# 145  0.0363 ('GDP', 'Population', 'Temperature_Avg', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.0363
# R-squared: 0.8043
# 146  0.0363 ('GDP', 'Population', 'Temperature_Avg', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 4})
# RMSE: 0.0379
# R-squared: 0.7862
# 147  0.0379 ('GDP', 'Population', 'Temperature_Avg', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.125, 'max_depth': 3})
# RMSE: 0.0761
# R-squared: 0.1398
# 148  0.0761 ('GDP', 'Population', 'Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 4})
# RMSE: 0.0778
# R-squared: 0.1011
# 149  0.0778 ('GDP', 'Population', 'Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 5})
# RMSE: 0.1023
# R-squared: -0.5546
# 150  0.1023 ('GDP', 'Population', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 4})
# RMSE: 0.0860
# R-squared: -0.0983
# 151  0.0860 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0404
# R-squared: 0.7579
# 152  0.0404 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.125, 'max_depth': 3})
# RMSE: 0.0753
# R-squared: 0.1585
# 153  0.0753 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0888
# R-squared: -0.1711
# 154  0.0888 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 3})
# RMSE: 0.0969
# R-squared: -0.3949
# 155  0.0969 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 3})
# RMSE: 0.0341
# R-squared: 0.8270
# 156  0.0341 ('GDP', 'Coal_Price', 'Automotive_LPG', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 3})
# RMSE: 0.0767
# R-squared: 0.1257
# 157  0.0767 ('GDP', 'Coal_Price', 'Automotive_LPG', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 4})
# RMSE: 0.0945
# R-squared: -0.3269
# 158  0.0945 ('GDP', 'Coal_Price', 'Automotive_LPG', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 5})
# RMSE: 0.0964
# R-squared: -0.3792
# 159  0.0964 ('GDP', 'Coal_Price', 'Automotive_LPG', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 3})
# RMSE: 0.0399
# R-squared: 0.7636
# 160  0.0399 ('GDP', 'Coal_Price', 'Temperature_Avg', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 5})
# RMSE: 0.0420
# R-squared: 0.7383
# 161  0.0420 ('GDP', 'Coal_Price', 'Temperature_Avg', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0413
# R-squared: 0.7464
# 162  0.0413 ('GDP', 'Coal_Price', 'Temperature_Avg', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.0752
# R-squared: 0.1595
# 163  0.0752 ('GDP', 'Coal_Price', 'Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 4})
# RMSE: 0.0809
# R-squared: 0.0280
# 164  0.0809 ('GDP', 'Coal_Price', 'Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 5})
# RMSE: 0.1030
# R-squared: -0.5759
# 165  0.1030 ('GDP', 'Coal_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 5})
# RMSE: 0.0367
# R-squared: 0.7997
# 166  0.0367 ('GDP', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 3})
# RMSE: 0.0743
# R-squared: 0.1800
# 167  0.0743 ('GDP', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 4})
# RMSE: 0.0843
# R-squared: -0.0558
# 168  0.0843 ('GDP', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0914
# R-squared: -0.2407
# 169  0.0914 ('GDP', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0391
# R-squared: 0.7733
# 170  0.0391 ('GDP', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 4})
# RMSE: 0.0356
# R-squared: 0.8113
# 171  0.0356 ('GDP', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0421
# R-squared: 0.7370
# 172  0.0421 ('GDP', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0711
# R-squared: 0.2494
# 173  0.0711 ('GDP', 'Regular_Unleaded_Petrol', 'Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 3})
# RMSE: 0.0777
# R-squared: 0.1024
# 174  0.0777 ('GDP', 'Regular_Unleaded_Petrol', 'Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 4})
# RMSE: 0.0957
# R-squared: -0.3618
# 175  0.0957 ('GDP', 'Regular_Unleaded_Petrol', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0371
# R-squared: 0.7957
# 176  0.0371 ('GDP', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 5})
# RMSE: 0.0356
# R-squared: 0.8119
# 177  0.0356 ('GDP', 'Automotive_LPG', 'Temperature_Avg', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.0368
# R-squared: 0.7988
# 178  0.0368 ('GDP', 'Automotive_LPG', 'Temperature_Avg', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 3})
# RMSE: 0.0749
# R-squared: 0.1676
# 179  0.0749 ('GDP', 'Automotive_LPG', 'Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.125, 'max_depth': 3})
# RMSE: 0.0785
# R-squared: 0.0846
# 180  0.0785 ('GDP', 'Automotive_LPG', 'Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0937
# R-squared: -0.3030
# 181  0.0937 ('GDP', 'Automotive_LPG', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0346
# R-squared: 0.8218
# 182  0.0346 ('GDP', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 5})
# RMSE: 0.0364
# R-squared: 0.8034
# 183  0.0364 ('GDP', 'Temperature_Avg', 'Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 4})
# RMSE: 0.0388
# R-squared: 0.7759
# 184  0.0388 ('GDP', 'Temperature_Avg', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 4})
# RMSE: 0.0778
# R-squared: 0.1019
# 185  0.0778 ('GDP', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.0980
# R-squared: -0.4279
# 186  0.0980 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 3})
# RMSE: 0.0397
# R-squared: 0.7658
# 187  0.0397 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 3})
# RMSE: 0.0931
# R-squared: -0.2867
# 188  0.0931 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.125, 'max_depth': 3})
# RMSE: 0.0962
# R-squared: -0.3739
# 189  0.0962 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 3})
# RMSE: 0.1037
# R-squared: -0.5966
# 190  0.1037 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 5})
# RMSE: 0.0387
# R-squared: 0.7777
# 191  0.0387 ('Population', 'Coal_Price', 'Automotive_LPG', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.1018
# R-squared: -0.5380
# 192  0.1018 ('Population', 'Coal_Price', 'Automotive_LPG', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 5})
# RMSE: 0.1074
# R-squared: -0.7119
# 193  0.1074 ('Population', 'Coal_Price', 'Automotive_LPG', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.1033
# R-squared: -0.5842
# 194  0.1033 ('Population', 'Coal_Price', 'Automotive_LPG', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 5})
# RMSE: 0.0418
# R-squared: 0.7404
# 195  0.0418 ('Population', 'Coal_Price', 'Temperature_Avg', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0413
# R-squared: 0.7465
# 196  0.0413 ('Population', 'Coal_Price', 'Temperature_Avg', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 5})
# RMSE: 0.0379
# R-squared: 0.7861
# 197  0.0379 ('Population', 'Coal_Price', 'Temperature_Avg', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 4})
# RMSE: 0.1110
# R-squared: -0.8300
# 198  0.1110 ('Population', 'Coal_Price', 'Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.0956
# R-squared: -0.3589
# 199  0.0956 ('Population', 'Coal_Price', 'Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 3})
# RMSE: 0.1144
# R-squared: -0.9430
# 200  0.1144 ('Population', 'Coal_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 4})
# RMSE: 0.0316
# R-squared: 0.8519
# 201  0.0316 ('Population', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0918
# R-squared: -0.2525
# 202  0.0918 ('Population', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0996
# R-squared: -0.4728
# 203  0.0996 ('Population', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 4})
# RMSE: 0.0965
# R-squared: -0.3842
# 204  0.0965 ('Population', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0334
# R-squared: 0.8346
# 205  0.0334 ('Population', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.125, 'max_depth': 3})
# RMSE: 0.0337
# R-squared: 0.8312
# 206  0.0337 ('Population', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0349
# R-squared: 0.8189
# 207  0.0349 ('Population', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.0875
# R-squared: -0.1369
# 208  0.0875 ('Population', 'Regular_Unleaded_Petrol', 'Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0923
# R-squared: -0.2655
# 209  0.0923 ('Population', 'Regular_Unleaded_Petrol', 'Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.1050
# R-squared: -0.6375
# 210  0.1050 ('Population', 'Regular_Unleaded_Petrol', 'Renewables_Production', 'Oil_Price')
# ...
# RMSE: 0.0387
# R-squared: 0.7775
# 414  0.0387 ('GDP', 'Population', 'Automotive_LPG', 'Temperature_Avg', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.0725
# R-squared: 0.2183
# 415  0.0725 ('GDP', 'Population', 'Automotive_LPG', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 4})
# RMSE: 0.0368
# R-squared: 0.7993
# 416  0.0368 ('GDP', 'Population', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 5})
# RMSE: 0.0420
# R-squared: 0.7377
# 417  0.0420 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 4})
# RMSE: 0.0377
# R-squared: 0.7890
# 418  0.0377 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0401
# R-squared: 0.7607
# 419  0.0401 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 3})
# RMSE: 0.0734
# R-squared: 0.1990
# 420  0.0734 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.0763
# R-squared: 0.1351
# 421  0.0763 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 4})
# RMSE: 0.0908
# R-squared: -0.2235
# 422  0.0908 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.0377
# R-squared: 0.7892
# 423  0.0377 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 5})
# RMSE: 0.0385
# R-squared: 0.7803
# 424  0.0385 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 5})
# RMSE: 0.0372
# R-squared: 0.7939
# 425  0.0372 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 3})
# RMSE: 0.0777
# R-squared: 0.1036
# 426  0.0777 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 4})
# RMSE: 0.0389
# R-squared: 0.7747
# 427  0.0389 ('GDP', 'Coal_Price', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.0390
# R-squared: 0.7743
# 428  0.0390 ('GDP', 'Coal_Price', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0377
# R-squared: 0.7893
# 429  0.0377 ('GDP', 'Coal_Price', 'Automotive_LPG', 'Temperature_Avg', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0764
# R-squared: 0.1328
# 430  0.0764 ('GDP', 'Coal_Price', 'Automotive_LPG', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 5})
# RMSE: 0.0378
# R-squared: 0.7883
# 431  0.0378 ('GDP', 'Coal_Price', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.0350
# R-squared: 0.8185
# 432  0.0350 ('GDP', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 5})
# RMSE: 0.0399
# R-squared: 0.7633
# 433  0.0399 ('GDP', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 5})
# RMSE: 0.0374
# R-squared: 0.7918
# 434  0.0374 ('GDP', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.0753
# R-squared: 0.1568
# 435  0.0753 ('GDP', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 4})
# RMSE: 0.0398
# R-squared: 0.7642
# 436  0.0398 ('GDP', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0350
# R-squared: 0.8183
# 437  0.0350 ('GDP', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 5})
# RMSE: 0.0403
# R-squared: 0.7590
# 438  0.0403 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.0401
# R-squared: 0.7611
# 439  0.0401 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 5})
# RMSE: 0.0371
# R-squared: 0.7958
# 440  0.0371 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.0982
# R-squared: -0.4326
# 441  0.0982 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.0952
# R-squared: -0.3468
# 442  0.0952 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.1025
# R-squared: -0.5597
# 443  0.1025 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 5})
# RMSE: 0.0425
# R-squared: 0.7319
# 444  0.0425 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0395
# R-squared: 0.7684
# 445  0.0395 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0371
# R-squared: 0.7950
# 446  0.0371 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 4})
# RMSE: 0.0935
# R-squared: -0.2992
# 447  0.0935 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 5})
# RMSE: 0.0401
# R-squared: 0.7616
# 448  0.0401 ('Population', 'Coal_Price', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 5})
# RMSE: 0.0385
# R-squared: 0.7803
# 449  0.0385 ('Population', 'Coal_Price', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 5})
# RMSE: 0.0376
# R-squared: 0.7905
# 450  0.0376 ('Population', 'Coal_Price', 'Automotive_LPG', 'Temperature_Avg', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.225, 'max_depth': 4})
# RMSE: 0.0969
# R-squared: -0.3961
# 451  0.0969 ('Population', 'Coal_Price', 'Automotive_LPG', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.2, 'max_depth': 5})
# RMSE: 0.0400
# R-squared: 0.7619
# 452  0.0400 ('Population', 'Coal_Price', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0314
# R-squared: 0.8539
# 453  0.0314 ('Population', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0358
# R-squared: 0.8098
# 454  0.0358 ('Population', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0327
# R-squared: 0.8413
# 455  0.0327 ('Population', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0934
# R-squared: -0.2951
# 456  0.0934 ('Population', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0336
# R-squared: 0.8318
# 457  0.0336 ('Population', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0342
# R-squared: 0.8260
# 458  0.0342 ('Population', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 5})
# RMSE: 0.0390
# R-squared: 0.7735
# 459  0.0390 ('Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 3})
# RMSE: 0.0512
# R-squared: 0.6105
# 460  0.0512 ('Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.175, 'max_depth': 5})
# RMSE: 0.0391
# R-squared: 0.7734
# 461  0.0391 ('Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 4})
# RMSE: 0.0949
# R-squared: -0.3376
# 462  0.0949 ('Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 5})
# RMSE: 0.0413
# R-squared: 0.7466
# 463  0.0413 ('Coal_Price', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.25, 'max_depth': 5})
# RMSE: 0.0405
# R-squared: 0.7565
# 464  0.0405 ('Coal_Price', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params GradientBoostingRegressor({'random_state': 0, 'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 3})
# RMSE: 0.0352
# R-squared: 0.8155
# 465  0.0352 ('Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
#                                               features  min_rmse  mean_rmse  \
# 115  (Regular_Unleaded_Petrol, Temperature_Avg, Oil...  0.020882   0.031512
# 242  (Regular_Unleaded_Petrol, Automotive_LPG, Temp...  0.022019   0.033206
# 121       (Automotive_LPG, Temperature_Avg, Oil_Price)  0.025685   0.032308
# 41                        (Temperature_Avg, Oil_Price)  0.026929   0.033629
# 246  (Regular_Unleaded_Petrol, Temperature_Avg, Ele...  0.031295   0.035439
# ..                                                 ...       ...        ...
# 32        (Regular_Unleaded_Petrol, Electricity_Price)  0.136374   0.145272
# 4                                    (Automotive_LPG,)  0.145720   0.145838
# 6                                 (Electricity_Price,)  0.152434   0.153757
# 2                                        (Coal_Price,)  0.165008   0.166223
# 3                           (Regular_Unleaded_Petrol,)  0.173309   0.173838
#
#        max_r2  num_features
# 115  0.935224             3
# 242  0.927982             4
# 121  0.902005             3
# 41   0.892283             2
# 246  0.854518             4
# ..        ...           ...
# 32  -1.762582             2
# 4   -2.154211             1
# 6   -2.451582             1
# 2   -3.044462             1
# 3   -3.461651             1
#
# [465 rows x 5 columns]

# %%
print(list(best_features.iloc[115]['features']))
print(', '.join(best_features.iloc[115]['features']))
print(', '.join(best_features.iloc[242]['features']))
print(', '.join(best_features.iloc[246]['features']))
print(best_features[['num_features', 'min_rmse', 'max_r2', 'mean_rmse']].groupby('num_features').agg({'min_rmse': 'min', 'max_r2': 'max', 'mean_rmse': 'count'}).reset_index().to_latex(index=False))
# Out:
# ['Regular_Unleaded_Petrol', 'Temperature_Avg', 'Oil_Price']
# Regular_Unleaded_Petrol, Temperature_Avg, Oil_Price
# Regular_Unleaded_Petrol, Automotive_LPG, Temperature_Avg, Oil_Price
# Regular_Unleaded_Petrol, Temperature_Avg, Electricity_Price, Renewables_Production
# \begin{tabular}{rrrr}
# \toprule
# num_features & min_rmse & max_r2 & mean_rmse \\
# \midrule
# 1 & 0.103759 & -0.599212 & 9 \\
# 2 & 0.026929 & 0.892283 & 36 \\
# 3 & 0.020882 & 0.935224 & 84 \\
# 4 & 0.022019 & 0.927982 & 126 \\
# 5 & 0.031303 & 0.854444 & 126 \\
# 6 & 0.031366 & 0.853857 & 84 \\
# \bottomrule
# \end{tabular}

# %%
# X_train, y_train, X_test, y_test = test_split(['Population',
#  'Coal_Price',
#  'Automotive_LPG',
#  'Temperature_Avg',
#  'Electricity_Price'])
# model, df_results, best_rmse = find_better_model(GradientBoostingRegressor, {
#                 'random_state': [0, 3, 5, 7, 11, 13, 19, 23],
#                 'n_estimators': [150, 200, 250],
#                 'learning_rate': [0.195, 0.2, 0.205, 0.2125, 0.223, 0.224, 0.225, 0.226, 0.227], # , 0.2375, 0.25, 0.275, 0.2875, 0.3, 0.03125],
#                 'max_depth': [3, 4, 5]
#                 })
# scatterplot(data=df_results, x='train_r2', y='test_r2', x2='train_rmse', y2='test_rmse', hue='n_estimators', style='learning_rate', title='R-squared', title2='RMSE')
# plot_full(model)

# %%
# X_train, y_train, X_test, y_test = test_split(['Population',
#  'Coal_Price',
#  'Automotive_LPG',
#  'Temperature_Avg',
#  'Electricity_Price'])
# model, df_results, best_rmse = find_better_model(GradientBoostingRegressor, {
#                 'random_state': [0, 3, 5, 7, 11, 13, 19, 23],
#                 'n_estimators': [150, 200, 250],
#                 'learning_rate': [0.175, 0.18, 0.185, 0.190, 0.195, 0.2, 0.205, 0.2125, 0.223, 0.224, 0.225, 0.226, 0.227], # , 0.2375, 0.25, 0.275, 0.2875, 0.3, 0.03125],
#                 'max_depth': [3, 4, 5]
#                 })
# scatterplot(data=df_results, x='train_r2', y='test_r2', x2='train_rmse', y2='test_rmse', hue='n_estimators', style='learning_rate', title='R-squared', title2='RMSE')
# plot_full(model)

# %%
# X_train, y_train, X_test, y_test = test_split(['Population',
#  'Coal_Price',
#  'Automotive_LPG',
#  'Temperature_Avg',
#  'Electricity_Price'])
# model, df_results, best_rmse = find_better_model(GradientBoostingRegressor, {
#                 'random_state': [0, 3, 5, 7, 11, 13, 19, 23],
#                 'n_estimators': [50, 100, 150, 200, 250],
#                 'learning_rate': [0.175, 0.18, 0.185, 0.1875, 0.190, 0.1925, 0.195, 0.2], #, 0.205, 0.2125, 0.223, 0.224, 0.225, 0.226, 0.227], # , 0.2375, 0.25, 0.275, 0.2875, 0.3, 0.03125],
#                 'max_depth': [3, 4, 5]
#                 })
# scatterplot(data=df_results, x='train_r2', y='test_r2', x2='train_rmse', y2='test_rmse', hue='n_estimators', style='max_depth', title='R-squared', title2='RMSE', file_name='gradient_boosting_train_v_test_scatter.png')
# plot_full(model, file_name='gradient_boosting_test_performance.png')

# %%
# features = ['Population',
#  'Coal_Price',
#  'Automotive_LPG',
#  'Temperature_Avg',
#  'Electricity_Price']
# X_train, y_train, X_test, y_test = test_split(features)
# print(f'Features: {features}')
# model, df_results, best_rmse = find_better_model(GradientBoostingRegressor, {
#                 'random_state': [0, 3, 5, 7, 11, 13, 19, 23],
#                 'n_estimators': [150, 200, 250],
#                 'learning_rate': [0.175, 0.18, 0.185, 0.187, 0.1875, 0.188, 0.188, 0.190, 0.1925, 0.195, 0.2], #, 0.205, 0.2125, 0.223, 0.224, 0.225, 0.226, 0.227], # , 0.2375, 0.25, 0.275, 0.2875, 0.3, 0.03125],
#                 'max_depth': [3, 4, 5]
#                 })
# scatterplot(data=df_results, x='train_r2', y='test_r2', x2='train_rmse', y2='test_rmse', hue='n_estimators', style='max_depth', title='R-squared', title2='RMSE', file_name='gradient_boosting_train_v_test_scatter.png')
# plot_full(model)

# %% [markdown]
# # Champion Model
# Tweaked the learning rate further but found no improvement over 0.188.
#
# This is the champion model.

# %%
features = ['Population',
 'Coal_Price',
 'Automotive_LPG',
 'Temperature_Avg',
 'Electricity_Price']
# features = ['Regular_Unleaded_Petrol', 'Temperature_Avg', 'Oil_Price']
X_train, y_train, X_test, y_test = test_split(features)
print(f'Features: {features}')
model, df_results, best_rmse = find_better_model(GradientBoostingRegressor, {
                'random_state': [0, 3, 5, 7, 11, 13, 19, 23],
                'n_estimators': [50, 100], #, 150, 200, 250],
                'learning_rate': [0.175, 0.18, 0.185, 0.187, 0.1873, 0.1875, 0.1877, 0.1879, 0.188, 0.1885, 0.190, 0.1925, 0.194, 0.195, 0.196, 0.2], #, 0.205, 0.2125, 0.223, 0.224, 0.225, 0.226, 0.227], # , 0.2375, 0.25, 0.275, 0.2875, 0.3, 0.03125],
                'max_depth': [3, 4, 5]
                })
scatterplot(data=df_results, x='train_r2', y='test_r2', x2='train_rmse', y2='test_rmse', hue='n_estimators', style='max_depth', title='R-squared', title2='RMSE', file_name='gradient_boosting_train_v_test_scatter.png')
plot_full(model, file_name='gradient_boosting_test_performance.png')
# Out:
# Features: ['Population', 'Coal_Price', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price']
# Best model with params GradientBoostingRegressor({'random_state': 7, 'n_estimators': 100, 'learning_rate': 0.175, 'max_depth': 5})
# RMSE: 0.0384
# R-squared: 0.7804

# %% [markdown]
# # XGBoost

# %%
X_train, y_train, X_test, y_test = test_split()
model, df_results, best_rmse = find_better_model(XGBRegressor, {
                'random_state': [0],
                # 'n_estimators': [100, 200],
                'learning_rate': [0.1, 0.15, 0.2, 0.25, 0.3, 0.325, 0.35, 0.375, 0.4],
                'max_depth': [3, 4, 5, 6, 7, 10]
                })
scatterplot(data=df_results, x='train_r2', y='test_r2', x2='train_rmse', y2='test_rmse', hue='max_depth', style='learning_rate', title='R-squared', title2='RMSE')
plot_full(model)
# Out:
# Best model with params XGBRegressor({'random_state': 0, 'learning_rate': 0.35, 'max_depth': 5})
# RMSE: 0.0364
# R-squared: 0.8036

# %%
best_features = find_best_features(XGBRegressor, {
                'random_state': [0],
                'objective': ['reg:squarederror'],
                # 'n_estimators': [100, 200],
                'learning_rate': [0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4],
                'max_depth': [3, 4, 5, 6]
                },
                min_features=1, max_features=6)
best_features['num_features'] = best_features['features'].apply(lambda x: len(x))
best_features.sort_values('min_rmse')
# Out:
# 465 combinations
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0988
# R-squared: -0.4491
#   1  0.0988 ('GDP',)
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1053
# R-squared: -0.6471
#   2  0.1053 ('Population',)
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1583
# R-squared: -2.7239
#   3  0.1583 ('Coal_Price',)
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1571
# R-squared: -2.6640
#   4  0.1571 ('Regular_Unleaded_Petrol',)
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1369
# R-squared: -1.7857
#   5  0.1369 ('Automotive_LPG',)
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 4})
# RMSE: 0.1251
# R-squared: -1.3252
#   6  0.1251 ('Temperature_Avg',)
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1329
# R-squared: -1.6252
#   7  0.1329 ('Electricity_Price',)
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1037
# R-squared: -0.5986
#   8  0.1037 ('Renewables_Production',)
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 5})
# RMSE: 0.0680
# R-squared: 0.3125
#   9  0.0680 ('Oil_Price',)
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0969
# R-squared: -0.3939
#  10  0.0969 ('GDP', 'Population')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0921
# R-squared: -0.2600
#  11  0.0921 ('GDP', 'Coal_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0846
# R-squared: -0.0640
#  12  0.0846 ('GDP', 'Regular_Unleaded_Petrol')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 5})
# RMSE: 0.0884
# R-squared: -0.1612
#  13  0.0884 ('GDP', 'Automotive_LPG')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 4})
# RMSE: 0.0387
# R-squared: 0.7774
#  14  0.0387 ('GDP', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 5})
# RMSE: 0.0798
# R-squared: 0.0537
#  15  0.0798 ('GDP', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0947
# R-squared: -0.3322
#  16  0.0947 ('GDP', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 3})
# RMSE: 0.0884
# R-squared: -0.1605
#  17  0.0884 ('GDP', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 5})
# RMSE: 0.1133
# R-squared: -0.9063
#  18  0.1133 ('Population', 'Coal_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0877
# R-squared: -0.1436
#  19  0.0877 ('Population', 'Regular_Unleaded_Petrol')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1009
# R-squared: -0.5111
#  20  0.1009 ('Population', 'Automotive_LPG')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 3})
# RMSE: 0.0341
# R-squared: 0.8270
#  21  0.0341 ('Population', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 4})
# RMSE: 0.0999
# R-squared: -0.4812
#  22  0.0999 ('Population', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1044
# R-squared: -0.6189
#  23  0.1044 ('Population', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 4})
# RMSE: 0.0934
# R-squared: -0.2959
#  24  0.0934 ('Population', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 3})
# RMSE: 0.1209
# R-squared: -1.1700
#  25  0.1209 ('Coal_Price', 'Regular_Unleaded_Petrol')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 3})
# RMSE: 0.0687
# R-squared: 0.2998
#  26  0.0687 ('Coal_Price', 'Automotive_LPG')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.1388
# R-squared: -1.8597
#  27  0.1388 ('Coal_Price', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1212
# R-squared: -1.1836
#  28  0.1212 ('Coal_Price', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1221
# R-squared: -1.2142
#  29  0.1221 ('Coal_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.1297
# R-squared: -1.4981
#  30  0.1297 ('Coal_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 6})
# RMSE: 0.1260
# R-squared: -1.3584
#  31  0.1260 ('Regular_Unleaded_Petrol', 'Automotive_LPG')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 4})
# RMSE: 0.1350
# R-squared: -1.7072
#  32  0.1350 ('Regular_Unleaded_Petrol', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 5})
# RMSE: 0.1243
# R-squared: -1.2939
#  33  0.1243 ('Regular_Unleaded_Petrol', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0833
# R-squared: -0.0315
#  34  0.0833 ('Regular_Unleaded_Petrol', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.0689
# R-squared: 0.2950
#  35  0.0689 ('Regular_Unleaded_Petrol', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 6})
# RMSE: 0.1004
# R-squared: -0.4967
#  36  0.1004 ('Automotive_LPG', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0999
# R-squared: -0.4817
#  37  0.0999 ('Automotive_LPG', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1025
# R-squared: -0.5621
#  38  0.1025 ('Automotive_LPG', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 5})
# RMSE: 0.0981
# R-squared: -0.4288
#  39  0.0981 ('Automotive_LPG', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 4})
# RMSE: 0.0361
# R-squared: 0.8060
#  40  0.0361 ('Temperature_Avg', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0336
# R-squared: 0.8327
#  41  0.0336 ('Temperature_Avg', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 5})
# RMSE: 0.0354
# R-squared: 0.8141
#  42  0.0354 ('Temperature_Avg', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1243
# R-squared: -1.2942
#  43  0.1243 ('Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 4})
# RMSE: 0.1144
# R-squared: -0.9424
#  44  0.1144 ('Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0941
# R-squared: -0.3157
#  45  0.0941 ('Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0945
# R-squared: -0.3254
#  46  0.0945 ('GDP', 'Population', 'Coal_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 3})
# RMSE: 0.0819
# R-squared: 0.0040
#  47  0.0819 ('GDP', 'Population', 'Regular_Unleaded_Petrol')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 5})
# RMSE: 0.0845
# R-squared: -0.0603
#  48  0.0845 ('GDP', 'Population', 'Automotive_LPG')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 4})
# RMSE: 0.0379
# R-squared: 0.7868
#  49  0.0379 ('GDP', 'Population', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.0790
# R-squared: 0.0733
#  50  0.0790 ('GDP', 'Population', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 5})
# RMSE: 0.0982
# R-squared: -0.4318
#  51  0.0982 ('GDP', 'Population', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 6})
# RMSE: 0.0845
# R-squared: -0.0612
#  52  0.0845 ('GDP', 'Population', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0800
# R-squared: 0.0482
#  53  0.0800 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 6})
# RMSE: 0.0811
# R-squared: 0.0223
#  54  0.0811 ('GDP', 'Coal_Price', 'Automotive_LPG')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0393
# R-squared: 0.7708
#  55  0.0393 ('GDP', 'Coal_Price', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 4})
# RMSE: 0.0739
# R-squared: 0.1888
#  56  0.0739 ('GDP', 'Coal_Price', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 6})
# RMSE: 0.0927
# R-squared: -0.2751
#  57  0.0927 ('GDP', 'Coal_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 3})
# RMSE: 0.0809
# R-squared: 0.0285
#  58  0.0809 ('GDP', 'Coal_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0849
# R-squared: -0.0719
#  59  0.0849 ('GDP', 'Regular_Unleaded_Petrol', 'Automotive_LPG')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 5})
# RMSE: 0.0370
# R-squared: 0.7965
#  60  0.0370 ('GDP', 'Regular_Unleaded_Petrol', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 4})
# RMSE: 0.0877
# R-squared: -0.1438
#  61  0.0877 ('GDP', 'Regular_Unleaded_Petrol', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0838
# R-squared: -0.0429
#  62  0.0838 ('GDP', 'Regular_Unleaded_Petrol', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0808
# R-squared: 0.0299
#  63  0.0808 ('GDP', 'Regular_Unleaded_Petrol', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 3})
# RMSE: 0.0352
# R-squared: 0.8155
#  64  0.0352 ('GDP', 'Automotive_LPG', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0811
# R-squared: 0.0226
#  65  0.0811 ('GDP', 'Automotive_LPG', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 4})
# RMSE: 0.0902
# R-squared: -0.2087
#  66  0.0902 ('GDP', 'Automotive_LPG', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 4})
# RMSE: 0.0860
# R-squared: -0.0996
#  67  0.0860 ('GDP', 'Automotive_LPG', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0381
# R-squared: 0.7843
#  68  0.0381 ('GDP', 'Temperature_Avg', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 5})
# RMSE: 0.0372
# R-squared: 0.7946
#  69  0.0372 ('GDP', 'Temperature_Avg', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 6})
# RMSE: 0.0387
# R-squared: 0.7771
#  70  0.0387 ('GDP', 'Temperature_Avg', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 6})
# RMSE: 0.0798
# R-squared: 0.0550
#  71  0.0798 ('GDP', 'Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0798
# R-squared: 0.0544
#  72  0.0798 ('GDP', 'Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 6})
# RMSE: 0.0846
# R-squared: -0.0633
#  73  0.0846 ('GDP', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0909
# R-squared: -0.2269
#  74  0.0909 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.1026
# R-squared: -0.5651
#  75  0.1026 ('Population', 'Coal_Price', 'Automotive_LPG')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 3})
# RMSE: 0.0382
# R-squared: 0.7830
#  76  0.0382 ('Population', 'Coal_Price', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 6})
# RMSE: 0.1143
# R-squared: -0.9410
#  77  0.1143 ('Population', 'Coal_Price', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 3})
# RMSE: 0.1180
# R-squared: -1.0694
#  78  0.1180 ('Population', 'Coal_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 6})
# RMSE: 0.1015
# R-squared: -0.5296
#  79  0.1015 ('Population', 'Coal_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 5})
# RMSE: 0.0942
# R-squared: -0.3177
#  80  0.0942 ('Population', 'Regular_Unleaded_Petrol', 'Automotive_LPG')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0346
# R-squared: 0.8219
#  81  0.0346 ('Population', 'Regular_Unleaded_Petrol', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.0893
# R-squared: -0.1844
#  82  0.0893 ('Population', 'Regular_Unleaded_Petrol', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0863
# R-squared: -0.1072
#  83  0.0863 ('Population', 'Regular_Unleaded_Petrol', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 6})
# RMSE: 0.0870
# R-squared: -0.1235
#  84  0.0870 ('Population', 'Regular_Unleaded_Petrol', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0340
# R-squared: 0.8282
#  85  0.0340 ('Population', 'Automotive_LPG', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 6})
# RMSE: 0.0975
# R-squared: -0.4126
#  86  0.0975 ('Population', 'Automotive_LPG', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0986
# R-squared: -0.4435
#  87  0.0986 ('Population', 'Automotive_LPG', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 6})
# RMSE: 0.0941
# R-squared: -0.3147
#  88  0.0941 ('Population', 'Automotive_LPG', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0329
# R-squared: 0.8393
#  89  0.0329 ('Population', 'Temperature_Avg', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 3})
# RMSE: 0.0328
# R-squared: 0.8405
#  90  0.0328 ('Population', 'Temperature_Avg', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0333
# R-squared: 0.8353
#  91  0.0333 ('Population', 'Temperature_Avg', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 4})
# RMSE: 0.1037
# R-squared: -0.5976
#  92  0.1037 ('Population', 'Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1074
# R-squared: -0.7128
#  93  0.1074 ('Population', 'Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 4})
# RMSE: 0.0930
# R-squared: -0.2861
#  94  0.0930 ('Population', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 3})
# RMSE: 0.0718
# R-squared: 0.2349
#  95  0.0718 ('Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 5})
# RMSE: 0.1068
# R-squared: -0.6944
#  96  0.1068 ('Coal_Price', 'Regular_Unleaded_Petrol', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0990
# R-squared: -0.4562
#  97  0.0990 ('Coal_Price', 'Regular_Unleaded_Petrol', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 4})
# RMSE: 0.0937
# R-squared: -0.3033
#  98  0.0937 ('Coal_Price', 'Regular_Unleaded_Petrol', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.1186
# R-squared: -1.0896
#  99  0.1186 ('Coal_Price', 'Regular_Unleaded_Petrol', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0459
# R-squared: 0.6871
# 100  0.0459 ('Coal_Price', 'Automotive_LPG', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 3})
# RMSE: 0.0975
# R-squared: -0.4110
# 101  0.0975 ('Coal_Price', 'Automotive_LPG', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 3})
# RMSE: 0.1036
# R-squared: -0.5930
# 102  0.1036 ('Coal_Price', 'Automotive_LPG', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 3})
# RMSE: 0.1076
# R-squared: -0.7198
# 103  0.1076 ('Coal_Price', 'Automotive_LPG', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 4})
# RMSE: 0.0437
# R-squared: 0.7161
# 104  0.0437 ('Coal_Price', 'Temperature_Avg', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0425
# R-squared: 0.7317
# 105  0.0425 ('Coal_Price', 'Temperature_Avg', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 5})
# RMSE: 0.1665
# R-squared: -3.1165
# 106  0.1665 ('Coal_Price', 'Temperature_Avg', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 5})
# RMSE: 0.1073
# R-squared: -0.7094
# 107  0.1073 ('Coal_Price', 'Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 6})
# RMSE: 0.1002
# R-squared: -0.4918
# 108  0.1002 ('Coal_Price', 'Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1061
# R-squared: -0.6716
# 109  0.1061 ('Coal_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 6})
# RMSE: 0.1141
# R-squared: -0.9347
# 110  0.1141 ('Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1135
# R-squared: -0.9151
# 111  0.1135 ('Regular_Unleaded_Petrol', 'Automotive_LPG', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 4})
# RMSE: 0.0985
# R-squared: -0.4409
# 112  0.0985 ('Regular_Unleaded_Petrol', 'Automotive_LPG', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 5})
# RMSE: 0.0928
# R-squared: -0.2785
# 113  0.0928 ('Regular_Unleaded_Petrol', 'Automotive_LPG', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 6})
# RMSE: 0.0323
# R-squared: 0.8447
# 114  0.0323 ('Regular_Unleaded_Petrol', 'Temperature_Avg', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0327
# R-squared: 0.8408
# 115  0.0327 ('Regular_Unleaded_Petrol', 'Temperature_Avg', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0300
# R-squared: 0.8659
# 116  0.0300 ('Regular_Unleaded_Petrol', 'Temperature_Avg', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0954
# R-squared: -0.3520
# 117  0.0954 ('Regular_Unleaded_Petrol', 'Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.1055
# R-squared: -0.6549
# 118  0.1055 ('Regular_Unleaded_Petrol', 'Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 5})
# RMSE: 0.0884
# R-squared: -0.1608
# 119  0.0884 ('Regular_Unleaded_Petrol', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0309
# R-squared: 0.8580
# 120  0.0309 ('Automotive_LPG', 'Temperature_Avg', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0339
# R-squared: 0.8297
# 121  0.0339 ('Automotive_LPG', 'Temperature_Avg', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 6})
# RMSE: 0.0308
# R-squared: 0.8587
# 122  0.0308 ('Automotive_LPG', 'Temperature_Avg', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 6})
# RMSE: 0.1013
# R-squared: -0.5248
# 123  0.1013 ('Automotive_LPG', 'Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 4})
# RMSE: 0.0990
# R-squared: -0.4569
# 124  0.0990 ('Automotive_LPG', 'Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 6})
# RMSE: 0.0970
# R-squared: -0.3989
# 125  0.0970 ('Automotive_LPG', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0375
# R-squared: 0.7908
# 126  0.0375 ('Temperature_Avg', 'Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 4})
# RMSE: 0.0316
# R-squared: 0.8519
# 127  0.0316 ('Temperature_Avg', 'Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 3})
# RMSE: 0.0339
# R-squared: 0.8290
# 128  0.0339 ('Temperature_Avg', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.1107
# R-squared: -0.8208
# 129  0.1107 ('Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0825
# R-squared: -0.0113
# 130  0.0825 ('GDP', 'Population', 'Coal_Price', 'Regular_Unleaded_Petrol')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 5})
# RMSE: 0.0900
# R-squared: -0.2039
# 131  0.0900 ('GDP', 'Population', 'Coal_Price', 'Automotive_LPG')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0390
# R-squared: 0.7746
# 132  0.0390 ('GDP', 'Population', 'Coal_Price', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 4})
# RMSE: 0.0753
# R-squared: 0.1574
# 133  0.0753 ('GDP', 'Population', 'Coal_Price', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0972
# R-squared: -0.4037
# 134  0.0972 ('GDP', 'Population', 'Coal_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 4})
# RMSE: 0.0837
# R-squared: -0.0410
# 135  0.0837 ('GDP', 'Population', 'Coal_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0805
# R-squared: 0.0363
# 136  0.0805 ('GDP', 'Population', 'Regular_Unleaded_Petrol', 'Automotive_LPG')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 6})
# RMSE: 0.0364
# R-squared: 0.8029
# 137  0.0364 ('GDP', 'Population', 'Regular_Unleaded_Petrol', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.0770
# R-squared: 0.1183
# 138  0.0770 ('GDP', 'Population', 'Regular_Unleaded_Petrol', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 3})
# RMSE: 0.0827
# R-squared: -0.0150
# 139  0.0827 ('GDP', 'Population', 'Regular_Unleaded_Petrol', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0829
# R-squared: -0.0205
# 140  0.0829 ('GDP', 'Population', 'Regular_Unleaded_Petrol', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 4})
# RMSE: 0.0355
# R-squared: 0.8132
# 141  0.0355 ('GDP', 'Population', 'Automotive_LPG', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0783
# R-squared: 0.0891
# 142  0.0783 ('GDP', 'Population', 'Automotive_LPG', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 4})
# RMSE: 0.0908
# R-squared: -0.2239
# 143  0.0908 ('GDP', 'Population', 'Automotive_LPG', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 4})
# RMSE: 0.0821
# R-squared: -0.0002
# 144  0.0821 ('GDP', 'Population', 'Automotive_LPG', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 6})
# RMSE: 0.0379
# R-squared: 0.7868
# 145  0.0379 ('GDP', 'Population', 'Temperature_Avg', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 4})
# RMSE: 0.0378
# R-squared: 0.7875
# 146  0.0378 ('GDP', 'Population', 'Temperature_Avg', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 5})
# RMSE: 0.0368
# R-squared: 0.7991
# 147  0.0368 ('GDP', 'Population', 'Temperature_Avg', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 5})
# RMSE: 0.0781
# R-squared: 0.0947
# 148  0.0781 ('GDP', 'Population', 'Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0767
# R-squared: 0.1256
# 149  0.0767 ('GDP', 'Population', 'Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 6})
# RMSE: 0.0845
# R-squared: -0.0598
# 150  0.0845 ('GDP', 'Population', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 4})
# RMSE: 0.0776
# R-squared: 0.1045
# 151  0.0776 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0342
# R-squared: 0.8261
# 152  0.0342 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 5})
# RMSE: 0.0772
# R-squared: 0.1143
# 153  0.0772 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 3})
# RMSE: 0.0832
# R-squared: -0.0288
# 154  0.0832 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 3})
# RMSE: 0.0774
# R-squared: 0.1096
# 155  0.0774 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0368
# R-squared: 0.7991
# 156  0.0368 ('GDP', 'Coal_Price', 'Automotive_LPG', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 6})
# RMSE: 0.0798
# R-squared: 0.0533
# 157  0.0798 ('GDP', 'Coal_Price', 'Automotive_LPG', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 5})
# RMSE: 0.0830
# R-squared: -0.0242
# 158  0.0830 ('GDP', 'Coal_Price', 'Automotive_LPG', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0790
# R-squared: 0.0722
# 159  0.0790 ('GDP', 'Coal_Price', 'Automotive_LPG', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 4})
# RMSE: 0.0419
# R-squared: 0.7395
# 160  0.0419 ('GDP', 'Coal_Price', 'Temperature_Avg', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0417
# R-squared: 0.7422
# 161  0.0417 ('GDP', 'Coal_Price', 'Temperature_Avg', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0336
# R-squared: 0.8323
# 162  0.0336 ('GDP', 'Coal_Price', 'Temperature_Avg', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 5})
# RMSE: 0.0747
# R-squared: 0.1707
# 163  0.0747 ('GDP', 'Coal_Price', 'Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 3})
# RMSE: 0.0795
# R-squared: 0.0602
# 164  0.0795 ('GDP', 'Coal_Price', 'Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 6})
# RMSE: 0.0850
# R-squared: -0.0722
# 165  0.0850 ('GDP', 'Coal_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 6})
# RMSE: 0.0364
# R-squared: 0.8035
# 166  0.0364 ('GDP', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 4})
# RMSE: 0.0885
# R-squared: -0.1636
# 167  0.0885 ('GDP', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0812
# R-squared: 0.0202
# 168  0.0812 ('GDP', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 3})
# RMSE: 0.0839
# R-squared: -0.0446
# 169  0.0839 ('GDP', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0358
# R-squared: 0.8101
# 170  0.0358 ('GDP', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 6})
# RMSE: 0.0369
# R-squared: 0.7983
# 171  0.0369 ('GDP', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0385
# R-squared: 0.7801
# 172  0.0385 ('GDP', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0772
# R-squared: 0.1150
# 173  0.0772 ('GDP', 'Regular_Unleaded_Petrol', 'Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0897
# R-squared: -0.1962
# 174  0.0897 ('GDP', 'Regular_Unleaded_Petrol', 'Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0847
# R-squared: -0.0648
# 175  0.0847 ('GDP', 'Regular_Unleaded_Petrol', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 6})
# RMSE: 0.0348
# R-squared: 0.8198
# 176  0.0348 ('GDP', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 3})
# RMSE: 0.0354
# R-squared: 0.8142
# 177  0.0354 ('GDP', 'Automotive_LPG', 'Temperature_Avg', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 6})
# RMSE: 0.0378
# R-squared: 0.7875
# 178  0.0378 ('GDP', 'Automotive_LPG', 'Temperature_Avg', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0790
# R-squared: 0.0734
# 179  0.0790 ('GDP', 'Automotive_LPG', 'Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0787
# R-squared: 0.0795
# 180  0.0787 ('GDP', 'Automotive_LPG', 'Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 4})
# RMSE: 0.0848
# R-squared: -0.0672
# 181  0.0848 ('GDP', 'Automotive_LPG', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 4})
# RMSE: 0.0374
# R-squared: 0.7920
# 182  0.0374 ('GDP', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 6})
# RMSE: 0.0347
# R-squared: 0.8209
# 183  0.0347 ('GDP', 'Temperature_Avg', 'Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 3})
# RMSE: 0.0352
# R-squared: 0.8155
# 184  0.0352 ('GDP', 'Temperature_Avg', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0772
# R-squared: 0.1144
# 185  0.0772 ('GDP', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 4})
# RMSE: 0.1019
# R-squared: -0.5411
# 186  0.1019 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0357
# R-squared: 0.8104
# 187  0.0357 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 4})
# RMSE: 0.0910
# R-squared: -0.2305
# 188  0.0910 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0932
# R-squared: -0.2915
# 189  0.0932 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0911
# R-squared: -0.2338
# 190  0.0911 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 3})
# RMSE: 0.0348
# R-squared: 0.8201
# 191  0.0348 ('Population', 'Coal_Price', 'Automotive_LPG', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 5})
# RMSE: 0.0926
# R-squared: -0.2729
# 192  0.0926 ('Population', 'Coal_Price', 'Automotive_LPG', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.1056
# R-squared: -0.6575
# 193  0.1056 ('Population', 'Coal_Price', 'Automotive_LPG', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0983
# R-squared: -0.4350
# 194  0.0983 ('Population', 'Coal_Price', 'Automotive_LPG', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 3})
# RMSE: 0.0360
# R-squared: 0.8076
# 195  0.0360 ('Population', 'Coal_Price', 'Temperature_Avg', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 3})
# RMSE: 0.0403
# R-squared: 0.7585
# 196  0.0403 ('Population', 'Coal_Price', 'Temperature_Avg', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0329
# R-squared: 0.8394
# 197  0.0329 ('Population', 'Coal_Price', 'Temperature_Avg', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.1039
# R-squared: -0.6037
# 198  0.1039 ('Population', 'Coal_Price', 'Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 5})
# RMSE: 0.0957
# R-squared: -0.3600
# 199  0.0957 ('Population', 'Coal_Price', 'Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 6})
# RMSE: 0.1005
# R-squared: -0.4996
# 200  0.1005 ('Population', 'Coal_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0344
# R-squared: 0.8239
# 201  0.0344 ('Population', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 6})
# RMSE: 0.1000
# R-squared: -0.4860
# 202  0.1000 ('Population', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 4})
# RMSE: 0.0926
# R-squared: -0.2747
# 203  0.0926 ('Population', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 4})
# RMSE: 0.0940
# R-squared: -0.3139
# 204  0.0940 ('Population', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 3})
# RMSE: 0.0343
# R-squared: 0.8250
# 205  0.0343 ('Population', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0343
# R-squared: 0.8257
# 206  0.0343 ('Population', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0342
# R-squared: 0.8258
# 207  0.0342 ('Population', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.0890
# R-squared: -0.1766
# 208  0.0890 ('Population', 'Regular_Unleaded_Petrol', 'Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 3})
# RMSE: 0.0952
# R-squared: -0.3459
# 209  0.0952 ('Population', 'Regular_Unleaded_Petrol', 'Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 5})
# RMSE: 0.0921
# R-squared: -0.2610
# 210  0.0921 ('Population', 'Regular_Unleaded_Petrol', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0332
# R-squared: 0.8365
# 211  0.0332 ('Population', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0349
# R-squared: 0.8191
# ...
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 3})
# RMSE: 0.0359
# R-squared: 0.8088
# 414  0.0359 ('GDP', 'Population', 'Automotive_LPG', 'Temperature_Avg', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0815
# R-squared: 0.0122
# 415  0.0815 ('GDP', 'Population', 'Automotive_LPG', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 6})
# RMSE: 0.0347
# R-squared: 0.8216
# 416  0.0347 ('GDP', 'Population', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0373
# R-squared: 0.7931
# 417  0.0373 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0361
# R-squared: 0.8067
# 418  0.0361 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0350
# R-squared: 0.8177
# 419  0.0350 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0756
# R-squared: 0.1510
# 420  0.0756 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 4})
# RMSE: 0.0809
# R-squared: 0.0289
# 421  0.0809 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0839
# R-squared: -0.0445
# 422  0.0839 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 4})
# RMSE: 0.0380
# R-squared: 0.7855
# 423  0.0380 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0359
# R-squared: 0.8085
# 424  0.0359 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0348
# R-squared: 0.8204
# 425  0.0348 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0785
# R-squared: 0.0856
# 426  0.0785 ('GDP', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0365
# R-squared: 0.8016
# 427  0.0365 ('GDP', 'Coal_Price', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 6})
# RMSE: 0.0344
# R-squared: 0.8237
# 428  0.0344 ('GDP', 'Coal_Price', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0360
# R-squared: 0.8074
# 429  0.0360 ('GDP', 'Coal_Price', 'Automotive_LPG', 'Temperature_Avg', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0777
# R-squared: 0.1043
# 430  0.0777 ('GDP', 'Coal_Price', 'Automotive_LPG', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0348
# R-squared: 0.8197
# 431  0.0348 ('GDP', 'Coal_Price', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 4})
# RMSE: 0.0355
# R-squared: 0.8123
# 432  0.0355 ('GDP', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0364
# R-squared: 0.8030
# 433  0.0364 ('GDP', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0349
# R-squared: 0.8191
# 434  0.0349 ('GDP', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 3})
# RMSE: 0.0798
# R-squared: 0.0537
# 435  0.0798 ('GDP', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 4})
# RMSE: 0.0352
# R-squared: 0.8163
# 436  0.0352 ('GDP', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 6})
# RMSE: 0.0340
# R-squared: 0.8284
# 437  0.0340 ('GDP', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0360
# R-squared: 0.8077
# 438  0.0360 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 3})
# RMSE: 0.0349
# R-squared: 0.8191
# 439  0.0349 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 3})
# RMSE: 0.0348
# R-squared: 0.8199
# 440  0.0348 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 6})
# RMSE: 0.0929
# R-squared: -0.2821
# 441  0.0929 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 4})
# RMSE: 0.0899
# R-squared: -0.2001
# 442  0.0899 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 3})
# RMSE: 0.0987
# R-squared: -0.4476
# 443  0.0987 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 3})
# RMSE: 0.0352
# R-squared: 0.8160
# 444  0.0352 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0334
# R-squared: 0.8340
# 445  0.0334 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0333
# R-squared: 0.8357
# 446  0.0333 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.3, 'max_depth': 4})
# RMSE: 0.0903
# R-squared: -0.2117
# 447  0.0903 ('Population', 'Coal_Price', 'Regular_Unleaded_Petrol', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 3})
# RMSE: 0.0362
# R-squared: 0.8048
# 448  0.0362 ('Population', 'Coal_Price', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.15, 'max_depth': 3})
# RMSE: 0.0353
# R-squared: 0.8146
# 449  0.0353 ('Population', 'Coal_Price', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0340
# R-squared: 0.8285
# 450  0.0340 ('Population', 'Coal_Price', 'Automotive_LPG', 'Temperature_Avg', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 6})
# RMSE: 0.0919
# R-squared: -0.2533
# 451  0.0919 ('Population', 'Coal_Price', 'Automotive_LPG', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0347
# R-squared: 0.8216
# 452  0.0347 ('Population', 'Coal_Price', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 3})
# RMSE: 0.0344
# R-squared: 0.8246
# 453  0.0344 ('Population', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0338
# R-squared: 0.8303
# 454  0.0338 ('Population', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0354
# R-squared: 0.8136
# 455  0.0354 ('Population', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 4})
# RMSE: 0.0978
# R-squared: -0.4194
# 456  0.0978 ('Population', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0345
# R-squared: 0.8233
# 457  0.0345 ('Population', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.25, 'max_depth': 3})
# RMSE: 0.0345
# R-squared: 0.8228
# 458  0.0345 ('Population', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 4})
# RMSE: 0.0378
# R-squared: 0.7880
# 459  0.0378 ('Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.1, 'max_depth': 3})
# RMSE: 0.0323
# R-squared: 0.8449
# 460  0.0323 ('Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0354
# R-squared: 0.8144
# 461  0.0354 ('Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.4, 'max_depth': 3})
# RMSE: 0.0943
# R-squared: -0.3199
# 462  0.0943 ('Coal_Price', 'Regular_Unleaded_Petrol', 'Automotive_LPG', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0356
# R-squared: 0.8118
# 463  0.0356 ('Coal_Price', 'Regular_Unleaded_Petrol', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.2, 'max_depth': 3})
# RMSE: 0.0366
# R-squared: 0.8007
# 464  0.0366 ('Coal_Price', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0348
# R-squared: 0.8203
# 465  0.0348 ('Regular_Unleaded_Petrol', 'Automotive_LPG', 'Temperature_Avg', 'Electricity_Price', 'Renewables_Production', 'Oil_Price')
#                                               features  min_rmse  mean_rmse  \
# 115  (Regular_Unleaded_Petrol, Temperature_Avg, Oil...  0.030050   0.048022
# 367  (Coal_Price, Regular_Unleaded_Petrol, Temperat...  0.030232   0.040980
# 121       (Automotive_LPG, Temperature_Avg, Oil_Price)  0.030842   0.039737
# 251  (Automotive_LPG, Temperature_Avg, Electricity_...  0.030856   0.034400
# 119  (Automotive_LPG, Temperature_Avg, Electricity_...  0.030915   0.036286
# ..                                                 ...       ...        ...
# 362  (Coal_Price, Regular_Unleaded_Petrol, Automoti...  0.153320   0.174204
# 3                           (Regular_Unleaded_Petrol,)  0.157055   0.171194
# 2                                        (Coal_Price,)  0.158333   0.183092
# 226  (Coal_Price, Regular_Unleaded_Petrol, Temperat...  0.164289   0.175776
# 105           (Coal_Price, Temperature_Avg, Oil_Price)  0.166471   0.176731
#
#        max_r2  num_features
# 115  0.865869             3
# 367  0.864236             5
# 121  0.858700             3
# 251  0.858577             4
# 119  0.858028             3
# ..        ...           ...
# 362 -2.491795             5
# 3   -2.664023             1
# 2   -2.723884             1
# 226 -3.009288             4
# 105 -3.116494             3
#
# [465 rows x 5 columns]

# %%
print(', '.join(best_features.iloc[115]['features']))
print(best_features[['num_features', 'min_rmse', 'max_r2', 'mean_rmse']].groupby('num_features').agg({'min_rmse': 'min', 'max_r2': 'max', 'mean_rmse': 'count'}).reset_index().to_latex(index=False))
best_features
# Out:
# Regular_Unleaded_Petrol, Temperature_Avg, Oil_Price
# \begin{tabular}{rrrr}
# \toprule
# num_features & min_rmse & max_r2 & mean_rmse \\
# \midrule
# 1 & 0.068034 & 0.312453 & 9 \\
# 2 & 0.033561 & 0.832688 & 36 \\
# 3 & 0.030050 & 0.865869 & 84 \\
# 4 & 0.030856 & 0.858577 & 126 \\
# 5 & 0.030232 & 0.864236 & 126 \\
# 6 & 0.032318 & 0.844858 & 84 \\
# \bottomrule
# \end{tabular}
#                                               features  min_rmse  mean_rmse  \
# 0                                               (GDP,)  0.098768   0.102781
# 1                                        (Population,)  0.105302   0.111700
# 2                                        (Coal_Price,)  0.158333   0.183092
# 3                           (Regular_Unleaded_Petrol,)  0.157055   0.171194
# 4                                    (Automotive_LPG,)  0.136942   0.144183
# ..                                                 ...       ...        ...
# 460  (Coal_Price, Regular_Unleaded_Petrol, Automoti...  0.035350   0.040978
# 461  (Coal_Price, Regular_Unleaded_Petrol, Automoti...  0.094265   0.100350
# 462  (Coal_Price, Regular_Unleaded_Petrol, Temperat...  0.035596   0.041290
# 463  (Coal_Price, Automotive_LPG, Temperature_Avg, ...  0.036625   0.041301
# 464  (Regular_Unleaded_Petrol, Automotive_LPG, Temp...  0.034780   0.037949
#
#        max_r2  num_features
# 0   -0.449055             1
# 1   -0.647107             1
# 2   -2.723884             1
# 3   -2.664023             1
# 4   -1.785660             1
# ..        ...           ...
# 460  0.814375             6
# 461 -0.319935             6
# 462  0.811784             6
# 463  0.800745             6
# 464  0.820315             6
#
# [465 rows x 5 columns]

# %%
features = ['Regular_Unleaded_Petrol',
 'Temperature_Avg',
 'Oil_Price']
X_train, y_train, X_test, y_test = test_split(features)
print(f'Features: {features}')
model, df_results, best_rmse = find_better_model(XGBRegressor, {
                'random_state': [0],
                'objective': ['reg:squarederror'],
                # 'n_estimators': [50, 100, 150, 200, 250],
                'learning_rate': [0.1875, 0.2, 0.2125, 0.225, 0.25, 0.275, 0.3, 0.325, 0.349, 0.35, 0.351, 0.375, 0.4], #, 0.205, 0.2125, 0.223, 0.224, 0.225, 0.226, 0.227], # , 0.2375, 0.25, 0.275, 0.2875, 0.3, 0.03125],
                'max_depth': [3, 4, 5, 6]
                })
scatterplot(data=df_results, x='train_r2', y='test_r2', x2='train_rmse', y2='test_rmse', hue='max_depth', style=None, title='R-squared', title2='RMSE', file_name='xgboost_train_v_test_scatter.png')
plot_full(model, file_name='xgboost_test_performance.png')
# Out:
# Features: ['Regular_Unleaded_Petrol', 'Temperature_Avg', 'Oil_Price']
# Best model with params XGBRegressor({'random_state': 0, 'objective': 'reg:squarederror', 'learning_rate': 0.35, 'max_depth': 3})
# RMSE: 0.0300
# R-squared: 0.8659
